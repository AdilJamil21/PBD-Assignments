# %% [markdown]
# # PBD ASSIGNMENT 1

# %% [raw]
# Name: Adil Jamil
# Roll: L1F20BSCS0832
# Section: D2

# %% [markdown]
# All the Functions have been Referenced from https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.pyplot.html

# %% [markdown]
# # QUESTION 1

# %%
import pandas as pd

# %%
df = pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
df['diagnosis'].head(154)
# Out:
# 0                       lung cancer
# 1                pulmonary hematoma
# 2                       lung cancer
# 3                 Inflammatory mass
# 4                       lung cancer
#                    ...
# 149     lung cancer(adenocarcinoma)
# 150    metastasis of uterine cancer
# 151                 susp. hamartoma
# 152                     lung cancer
# 153           susp. lung metastasis
# Name: diagnosis, Length: 154, dtype: object

# %%
import numpy as np

# %%
df.replace("?",np.nan,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
df['diagnosis'].head(154)
# Out:
# 0                       lung cancer
# 1                pulmonary hematoma
# 2                       lung cancer
# 3                 Inflammatory mass
# 4                       lung cancer
#                    ...
# 149     lung cancer(adenocarcinoma)
# 150    metastasis of uterine cancer
# 151                 susp. hamartoma
# 152                     lung cancer
# 153           susp. lung metastasis
# Name: diagnosis, Length: 154, dtype: object

# %%
#Finding Total No. of Patients for Each Disease.
df['diagnosis'].value_counts()
# Out:
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# ...

# %% [raw]
# In the Above Command we can see Total Number of Patients for each disease as the Highest count of Patients belong to Lung Cancer and Lung Cancer(adenocarcinoma).

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.title('Diagnosis')
plt.pyplot.xlabel('Total Number of Each type of Disease')
plt.pyplot.ylabel('Frequency')
plt.pyplot.hist(df['diagnosis'].value_counts())
# Out:
# (array([27.,  2.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 1. ,  6.5, 12. , 17.5, 23. , 28.5, 34. , 39.5, 45. , 50.5, 56. ]),
#  <BarContainer object of 10 artists>)

# %% [raw]
# The Above Histogram Shows that the Frequency of Different types of diseases is more but the disease with Lung Cancer with Number of Patients with Different Diseases have more Frequency than the Diseases with Patients > 10.

# %% [markdown]
# # QUESTION 2

# %%
plt.pyplot.pie(df.loc[df['diagnosis'] == 'lung cancer']['state'].value_counts(), labels = ['malignant'], autopct = '%1.1f%%')
df.loc[df['diagnosis'] == 'lung cancer']['state'].value_counts()
# Out:
# malignant    56
# Name: state, dtype: int64

# %% [raw]
# As By using loc command we can compare two Columns and values to create pie chart. But this will take long time to
# calculate every pie chart, so we will use Loops.

# %%
for x in list(df['diagnosis'].unique()):
#To Create New PieChart everytime and not to overwrite the previous. 
    plt.pyplot.figure()
    plt.pyplot.pie(df.loc[df['diagnosis'] == x]['state'].value_counts(), labels = list(df.loc[df['diagnosis'] == x]['state'].value_counts().keys()), autopct = '%1.1f%%')

#To show which type of disease is in which state we will use legend command.  
    plt.pyplot.legend(title= x)
    print(df.loc[df['diagnosis'] == x]['state'].value_counts())
# Out:
# malignant    56
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# benign    14
# Name: state, dtype: int64
# benign    8
# Name: state, dtype: int64
# malignant    23
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# benign    4
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# malignant    7
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# malignant    2
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# benign    3
# Name: state, dtype: int64
# malignant    4
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# benign    4
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# ...

# %% [markdown]
# # QUESTION 3

# %%
plt.pyplot.pie(df.loc[df['diagnosis'] == 'lung cancer']['gender'].value_counts(), labels = ['female', 'male'], autopct = '%1.1f%%')
df.loc[df['diagnosis'] == 'lung cancer']['gender'].value_counts()
# Out:
# Female    32
# Male      24
# Name: gender, dtype: int64

# %% [raw]
# #NOW APPLYING LOOPS...

# %%
for x in list(df['diagnosis'].unique()):
#To Create New PieChart everytime and not to overwrite the previous. 
    plt.pyplot.figure()
    plt.pyplot.pie(df.loc[df['diagnosis'] == x]['gender'].value_counts(), labels = list(df.loc[df['diagnosis'] == x]['gender'].value_counts().keys()), autopct = '%1.1f%%')

#To show which type of disease is in which state we will use legend command.  
    plt.pyplot.legend(title= x)
    print(df.loc[df['diagnosis'] == x]['gender'].value_counts())
# Out:
# Female    32
# Male      24
# Name: gender, dtype: int64
# Female    1
# Male      1
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Male      9
# Female    5
# Name: gender, dtype: int64
# Male      6
# Female    2
# Name: gender, dtype: int64
# Female    15
# Male       8
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Female    4
# Name: gender, dtype: int64
# Male      1
# Female    1
# Name: gender, dtype: int64
# Female    4
# Male      3
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Male    2
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Male    3
# Name: gender, dtype: int64
# Female    3
# Male      1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    2
# Male      2
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Male      1
# Female    1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# ...
